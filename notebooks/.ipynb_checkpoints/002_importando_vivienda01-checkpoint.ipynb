# %%
import pandas as pd

# %%
f = "../data/001_raw/vivienda01/comedor - sensor dennis - de 5 de noviembre al 22 de noviembre.csv"
comedor = pd.read_csv(f,index_col=1,parse_dates=True,dayfirst=False)
comedor

f = "../data/001_raw/vivienda01/dormitorio - sensor 20809036 - de 5 de noviembre al 22 de noviembre.csv"
dormitorio = pd.read_csv(f,index_col=1,parse_dates=True,dayfirst=False)
dormitorio

f = "../data/001_raw/vivienda01/sala - sensor richard - de 5 de noviembre al 22 de noviembre.csv"
sala = pd.read_csv(f,index_col=1,parse_dates=True,dayfirst=False)
sala
# Out:
#                                       #  Temperature   (°C)  RH   (%)  \
# Date-Time (Ecuador Standard Time)
# 2024-11-05 08:42:31                   1                 NaN       NaN
# 2024-11-05 10:00:00                   2               31.36     64.71
# 2024-11-05 10:05:00                   3               31.63     64.88
# 2024-11-05 10:10:00                   4               31.92     70.34
# 2024-11-05 10:15:00                   5               32.07     63.28
# ...                                 ...                 ...       ...
# 2024-11-22 08:20:00                4878               24.16     87.01
# 2024-11-22 08:25:00                4879               24.18     87.20
# 2024-11-22 08:30:00                4880               24.19     86.76
# 2024-11-22 08:35:00                4881               24.19     86.44
# 2024-11-22 08:38:42                4882                 NaN       NaN
#
#                                    Dew Point   (°C) Host Connected End of File
# Date-Time (Ecuador Standard Time)
# 2024-11-05 08:42:31                             NaN         Logged         NaN
# 2024-11-05 10:00:00                           23.94            NaN         NaN
# 2024-11-05 10:05:00                           24.24            NaN         NaN
# 2024-11-05 10:10:00                           25.87            NaN         NaN
# 2024-11-05 10:15:00                           24.23            NaN         NaN
# ...                                             ...            ...         ...
# 2024-11-22 08:20:00                           21.89            NaN         NaN
# 2024-11-22 08:25:00                           21.95            NaN         NaN
# 2024-11-22 08:30:00                           21.88            NaN         NaN
# 2024-11-22 08:35:00                           21.81            NaN         NaN
# 2024-11-22 08:38:42                             NaN         Logged      Logged
#
# [4882 rows x 6 columns]
